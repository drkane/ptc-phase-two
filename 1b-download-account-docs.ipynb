# %% [markdown]
# # Download account documents from a list
#
# @todo:
#
# - support pagination of accounts to find older documents

# %% [markdown]
# ## Setup the download

# %%
import requests
from requests.auth import HTTPBasicAuth
import csv
from tqdm import tqdm_notebook
import pandas as pd
import requests_cache

# %% [markdown]
# Use the `requests_cache` module to prevent multiple requests to the same URL

# %%
requests_cache.install_cache('http_cache')

# %% [markdown]
# Get a Companies House API key

# %%
with open('api_key.txt') as a:
    API_KEY = a.read()

# %% [markdown]
# URL of the filing history for a company (designed to use with `.format()`)

# %%
filing_history_url = 'https://api.companieshouse.gov.uk/company/{}/filing-history'

# %% [markdown]
# ## Fetch organisation numbers to download
#
# Company & charity numbers

# %%
orgs = []
with open('orgs-to-check/ptc.csv') as c:
    reader = csv.reader(c)
    orgs = [r for r in reader]

# %%
companies = [o[0].replace("GB-COH-", "") for o in orgs if o[0].startswith("GB-COH-") and len(o[0])==15]
charities = [o[0].replace("GB-CHC-", "") for o in orgs if o[0].startswith("GB-CHC-") and len(o[0]) in [13,14]]
"{:,.0f} companies and {:,.0f} charities to find".format(len(companies), len(charities))
# Out:
# '563 companies and 444 charities to find'

# %% [markdown]
# ## Fetch documents for companies

# %% [markdown]
# For each registered company fetch the metadata about the first record in their filing history

# %%
filing_history = []
for company_number in tqdm_notebook(companies):
    r = requests.get(filing_history_url.format(company_number), auth=HTTPBasicAuth(API_KEY, ''))
    if 'items' in r.json():
        for i in r.json()['items']:
            # make sure we're getting the right kind of records
            if i['category']=='accounts' and i['description'].startswith('accounts-'):
                filing_history.append(i)
                break
# Out:
# HBox(children=(IntProgress(value=0, max=563), HTML(value='')))

# %%
filing_history = pd.DataFrame(pd.io.json.json_normalize(filing_history))
"{:,.0f} accounts found".format(len(filing_history))
# Out:
# '363 accounts found'

# %% [markdown]
# Show the types of accounts

# %%
filing_history['description'].value_counts()
# Out:
# accounts-with-accounts-type-total-exemption-full            198
# accounts-with-accounts-type-micro-entity                    110
# accounts-with-accounts-type-dormant                          15
# accounts-with-accounts-type-small                            12
# accounts-with-accounts-type-unaudited-abridged                8
# accounts-with-accounts-type-total-exemption-small             7
# accounts-amended-with-accounts-type-total-exemption-full      5
# accounts-with-accounts-type-full                              4
# accounts-with-accounts-type-group                             4
# Name: description, dtype: int64

# %%
filing_history['paper_filed'].value_counts(dropna=False)
# Out:
# True    250
# NaN     113
# Name: paper_filed, dtype: int64

# %%
results = {}

# Go through each account we're looking for
for k, f in tqdm_notebook(filing_history[filing_history['links.document_metadata'].notnull()].iterrows()):
    
    # fetch the document metadata
    r = requests.get(f['links.document_metadata'], auth=HTTPBasicAuth(API_KEY, ''))
    filetype = 'pdf'
    content_type = 'application/pdf'
    try:
        _ = r.json()
    except:
        r.headers
        continue

    # if it looks like there's XBRL data then request than
    if 'application/xhtml+xml' in r.json().get('resources'):
        filetype = 'html'
        content_type = 'application/xhtml+xml'
        
    # fetch the actual document
    doc = requests.get(
        r.json()['links']['document'],
        auth=HTTPBasicAuth(API_KEY, ''),
        headers={"Accept": content_type}
    )
    
    action_date = f['description_values.made_up_date']
    
    # work out the filename we're going to use
    filename = 'accounts/GB-COH-{}-{}.{}'.format(
        r.json().get('company_number'),
        action_date,
        filetype
    )
        
    # add to our results
    results[k] = {
        "filename": filename,
        "filetype": filetype,
        "company_number": r.json().get('company_number')
    }
    
    # write the file to the file system
    with open(filename, 'wb') as a:
        _ = a.write(doc.content)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
filing_history = filing_history.drop(columns=['filename', 'filetype', 'company_number'], errors='ignore').join(pd.DataFrame(results).T, how='left')

# %%
filing_history['filetype'].value_counts(dropna=False)
# Out:
# pdf     246
# html    111
# NaN       6
# Name: filetype, dtype: int64

# %%
filing_history.to_csv('company_accounts.csv')

# %%
pd.crosstab(
    filing_history['filetype'],
    filing_history['paper_filed'].fillna(False)
)
# Out:
# paper_filed  False  True
# filetype
# html           111      0
# pdf              2    244

# %% [markdown]
# ## Fetch documents for charities

# %%
from bs4 import BeautifulSoup
import datetime

# %%
cc_url = 'http://beta.charitycommission.gov.uk/charity-details/?regid={}&subid=0'

# %%
accounts = []
for c in tqdm_notebook(charities):
    r = requests.get(cc_url.format(c))
    soup = BeautifulSoup(r.text, 'html.parser')
    for a in soup.select('div.doc-container'):
        link = a.find(class_='doc')
        accounts.append({
            "charity_number": c,
            "accounts_url": link.get('href'),
            "financial_year_end": datetime.datetime.strptime(link.find(class_='doc-name').get_text(), '%d %b %Y')
        })
# Out:
# HBox(children=(IntProgress(value=0, max=444), HTML(value='')))

# %%
accounts = pd.DataFrame(accounts)

# %%
latest_accounts = accounts.sort_values(["charity_number", "financial_year_end"]).groupby("charity_number").last()
results = {}
for c, a in tqdm_notebook(latest_accounts.iterrows()):
    filename = 'accounts/GB-CHC-{}-{}.{}'.format(
        c,
        a['financial_year_end'].strftime('%Y-%m-%d'),
        'pdf'
    )
    
    doc = requests.get(a['accounts_url'])
    results[a['accounts_url']] = filename
    
    # write the file to the file system
    with open(filename, 'wb') as a:
        _ = a.write(doc.content)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
accounts = accounts.join(pd.Series(results).rename('filename'), how='left', on='accounts_url')

# %%
accounts.to_csv('charity_accounts.csv')

# %% [markdown]
# ## Generate a merged list with the accounts downloaded and a list of the files

# %%
filing_history
# Out:
#     action_date   barcode  category        date  \
# 0    2017-09-30  X71YYNOQ  accounts  2018-03-18
# 1    2017-03-31  A6LN6R4I  accounts  2017-12-28
# 2    2017-03-31  A6XUJXEY  accounts  2018-01-18
# 3    2017-07-31  A6KFOPYU  accounts  2017-12-08
# 4    2017-06-30  A6LSSZPT  accounts  2018-01-03
# 5    2017-03-31  L6M7R6CX  accounts  2018-01-05
# 6    2017-10-31  X78DMLU3  accounts  2018-06-18
# 7    2017-03-31  X6K8IG57  accounts  2017-11-29
# 8    2017-03-31  X6LJZAMH  accounts  2017-12-18
# 9    2017-12-31  A7HP6LXD  accounts  2018-11-07
# 361  2018-03-31  X7JJORHT  accounts  2018-11-26
# 362  2016-07-31  A66M0VXS  accounts  2017-05-23
#
#                                            description  \
# 0             accounts-with-accounts-type-micro-entity
# 1                     accounts-with-accounts-type-full
# 2     accounts-with-accounts-type-total-exemption-full
# 3                    accounts-with-accounts-type-small
# 4                     accounts-with-accounts-type-full
# 5     accounts-with-accounts-type-total-exemption-full
# 6     accounts-with-accounts-type-total-exemption-full
# 7     accounts-with-accounts-type-total-exemption-full
# 8     accounts-with-accounts-type-total-exemption-full
# 9     accounts-with-accounts-type-total-exemption-full
# 10                   accounts-with-accounts-type-small
# 11    accounts-with-accounts-type-total-exemption-full
# 12    accounts-with-accounts-type-total-exemption-full
# 13            accounts-with-accounts-type-micro-entity
# 14                   accounts-with-accounts-type-small
# 15    accounts-with-accounts-type-total-exemption-full
# 16                   accounts-with-accounts-type-group
# 17    accounts-with-accounts-type-total-exemption-full
# 18            accounts-with-accounts-type-micro-entity
# 19            accounts-with-accounts-type-micro-entity
# 20                   accounts-with-accounts-type-group
# 21                   accounts-with-accounts-type-small
# 22            accounts-with-accounts-type-micro-entity
# 23                   accounts-with-accounts-type-small
# 24            accounts-with-accounts-type-micro-entity
# 25            accounts-with-accounts-type-micro-entity
# 26            accounts-with-accounts-type-micro-entity
# 27   accounts-with-accounts-type-total-exemption-small
# 28    accounts-with-accounts-type-total-exemption-full
# 29            accounts-with-accounts-type-micro-entity
# ..                                                 ...
# 333   accounts-with-accounts-type-total-exemption-full
# 334           accounts-with-accounts-type-micro-entity
# 335   accounts-with-accounts-type-total-exemption-full
# 336   accounts-with-accounts-type-total-exemption-full
# 337   accounts-with-accounts-type-total-exemption-full
# 338                accounts-with-accounts-type-dormant
# 339           accounts-with-accounts-type-micro-entity
# 340   accounts-with-accounts-type-total-exemption-full
# 341           accounts-with-accounts-type-micro-entity
# 342                accounts-with-accounts-type-dormant
# 343   accounts-with-accounts-type-total-exemption-full
# 344           accounts-with-accounts-type-micro-entity
# 345           accounts-with-accounts-type-micro-entity
# 346           accounts-with-accounts-type-micro-entity
# 347   accounts-with-accounts-type-total-exemption-full
# 348   accounts-with-accounts-type-total-exemption-full
# 349   accounts-with-accounts-type-total-exemption-full
# 350   accounts-with-accounts-type-total-exemption-full
# 351                accounts-with-accounts-type-dormant
# 352           accounts-with-accounts-type-micro-entity
# 353   accounts-with-accounts-type-total-exemption-full
# 354   accounts-with-accounts-type-total-exemption-full
# 355   accounts-with-accounts-type-total-exemption-full
# 356           accounts-with-accounts-type-micro-entity
# 357           accounts-with-accounts-type-micro-entity
# 358   accounts-with-accounts-type-total-exemption-full
# 359   accounts-with-accounts-type-total-exemption-full
# 360                  accounts-with-accounts-type-small
# 361           accounts-with-accounts-type-micro-entity
# 362   accounts-with-accounts-type-total-exemption-full
#
#     description_values.made_up_date  \
# 0                        2017-09-30
# 1                        2017-03-31
# 2                        2017-03-31
# 3                        2017-07-31
# 4                        2017-06-30
# 5                        2017-03-31
# 6                        2017-10-31
# 7                        2017-03-31
# 8                        2017-03-31
# 9                        2017-12-31
# 10                       2017-03-31
# 11                       2017-03-31
# 12                       2017-03-31
# 13                       2017-10-31
# 14                       2017-12-31
# 15                       2017-05-31
# 16                       2017-03-31
# 17                       2017-09-30
# 18                       2017-03-31
# 19                       2018-03-31
# 20                       2017-03-31
# 21                       2017-12-31
# 22                       2017-03-31
# 23                       2017-03-31
# 24                       2017-07-31
# 25                       2017-03-31
# 26                       2017-03-31
# 27                       2013-03-31
# 28                       2017-03-31
# 29                       2017-03-31
# ..                              ...
# 333                      2017-06-30
# 334                      2017-06-30
# 335                      2017-07-31
# 336                      2017-07-31
# 337                      2017-12-31
# 338                      2017-08-31
# 339                      2017-09-30
# 340                      2017-09-30
# 341                      2017-10-31
# 342                      2017-10-31
# 343                      2018-03-31
# 344                      2017-11-30
# 345                      2017-11-30
# 346                      2017-03-31
# 347                      2018-03-31
# 348                      2017-11-30
# 349                      2017-11-30
# 350                      2017-08-31
# 351                      2017-12-31
# 352                      2018-03-31
# 353                      2018-03-31
# 354                      2017-12-31
# 355                      2018-03-31
# 356                      2018-01-31
# 357                      2018-01-31
# 358                      2018-01-26
# 359                      2018-03-31
# 360                      2017-12-31
# 361                      2018-03-31
# 362                      2016-07-31
#
#                                links.document_metadata  \
# 0    https://frontend-doc-api.companieshouse.gov.uk...
# 1    https://frontend-doc-api.companieshouse.gov.uk...
# 2    https://frontend-doc-api.companieshouse.gov.uk...
# 3    https://frontend-doc-api.companieshouse.gov.uk...
# 4    https://frontend-doc-api.companieshouse.gov.uk...
# 5    https://frontend-doc-api.companieshouse.gov.uk...
# 6    https://frontend-doc-api.companieshouse.gov.uk...
# 7    https://frontend-doc-api.companieshouse.gov.uk...
# 8    https://frontend-doc-api.companieshouse.gov.uk...
# 9    https://frontend-doc-api.companieshouse.gov.uk...
# 10   https://frontend-doc-api.companieshouse.gov.uk...
# 11   https://frontend-doc-api.companieshouse.gov.uk...
# 12   https://frontend-doc-api.companieshouse.gov.uk...
# 13   https://frontend-doc-api.companieshouse.gov.uk...
# 14   https://frontend-doc-api.companieshouse.gov.uk...
# 15   https://frontend-doc-api.companieshouse.gov.uk...
# 16   https://frontend-doc-api.companieshouse.gov.uk...
# 17   https://frontend-doc-api.companieshouse.gov.uk...
# 18   https://frontend-doc-api.companieshouse.gov.uk...
# 19   https://frontend-doc-api.companieshouse.gov.uk...
# 20   https://frontend-doc-api.companieshouse.gov.uk...
# 21   https://frontend-doc-api.companieshouse.gov.uk...
# 22   https://frontend-doc-api.companieshouse.gov.uk...
# 23   https://frontend-doc-api.companieshouse.gov.uk...
# 24   https://frontend-doc-api.companieshouse.gov.uk...
# 25   https://frontend-doc-api.companieshouse.gov.uk...
# 26   https://frontend-doc-api.companieshouse.gov.uk...
# 27   https://frontend-doc-api.companieshouse.gov.uk...
# 28   https://frontend-doc-api.companieshouse.gov.uk...
# 29   https://frontend-doc-api.companieshouse.gov.uk...
# ..                                                 ...
# 333  https://frontend-doc-api.companieshouse.gov.uk...
# 334  https://frontend-doc-api.companieshouse.gov.uk...
# 335  https://frontend-doc-api.companieshouse.gov.uk...
# 336  https://frontend-doc-api.companieshouse.gov.uk...
# 337  https://frontend-doc-api.companieshouse.gov.uk...
# 338  https://frontend-doc-api.companieshouse.gov.uk...
# 339  https://frontend-doc-api.companieshouse.gov.uk...
# 340  https://frontend-doc-api.companieshouse.gov.uk...
# 341  https://frontend-doc-api.companieshouse.gov.uk...
# 342  https://frontend-doc-api.companieshouse.gov.uk...
# 343  https://frontend-doc-api.companieshouse.gov.uk...
# 344  https://frontend-doc-api.companieshouse.gov.uk...
# 345  https://frontend-doc-api.companieshouse.gov.uk...
# 346  https://frontend-doc-api.companieshouse.gov.uk...
# 347  https://frontend-doc-api.companieshouse.gov.uk...
# 348  https://frontend-doc-api.companieshouse.gov.uk...
# 349  https://frontend-doc-api.companieshouse.gov.uk...
# 350  https://frontend-doc-api.companieshouse.gov.uk...
# 351  https://frontend-doc-api.companieshouse.gov.uk...
# 352  https://frontend-doc-api.companieshouse.gov.uk...
# 353  https://frontend-doc-api.companieshouse.gov.uk...
# 354  https://frontend-doc-api.companieshouse.gov.uk...
# 355  https://frontend-doc-api.companieshouse.gov.uk...
# 356  https://frontend-doc-api.companieshouse.gov.uk...
# 357  https://frontend-doc-api.companieshouse.gov.uk...
# 358  https://frontend-doc-api.companieshouse.gov.uk...
# 359  https://frontend-doc-api.companieshouse.gov.uk...
# 360  https://frontend-doc-api.companieshouse.gov.uk...
# 361  https://frontend-doc-api.companieshouse.gov.uk...
# 362  https://frontend-doc-api.companieshouse.gov.uk...
#
#                                             links.self  pages paper_filed  \
# 0    /company/00889858/filing-history/MzIwMDMwODMyN...    6.0         NaN
# 1    /company/01759876/filing-history/MzE5MzU3NDM0O...   16.0        True
# 2    /company/02203518/filing-history/MzE5NTU4ODg2N...   22.0        True
# 3    /company/02381821/filing-history/MzE5MjIxMTA2O...   21.0        True
# 4    /company/02599428/filing-history/MzE5NDM2NjAzN...   43.0        True
# 5    /company/02608803/filing-history/MzE5NDU2NTIyN...    4.0        True
# 6    /company/02978957/filing-history/MzIwNzYxNjAwM...    5.0         NaN
# 7    /company/03054343/filing-history/MzE5MTUwMzgxN...   11.0         NaN
# 8    /company/03171108/filing-history/MzE5MzExOTM0N...    8.0         NaN
# 9    /company/03296566/filing-history/MzIxODU5NDcwO...   21.0        True
# 10   /company/03513202/filing-history/MzE5MzMyNzAxO...   28.0        True
# 11   /company/03591314/filing-history/MzE5MjEzMDI2O...   26.0        True
# 12   /company/03648122/filing-history/MzE5NDUwMzY4N...   34.0        True
# 13   /company/03874497/filing-history/MzIwNDg2MDU1O...    3.0         NaN
# 14   /company/03909555/filing-history/MzIxNjMxODYzN...   27.0        True
# 15   /company/04001326/filing-history/MzE5ODAwMjkzN...    9.0         NaN
# 16   /company/04160469/filing-history/MzE5Mjk4NzY0M...   20.0        True
# 17   /company/04173535/filing-history/MzIxNzAxNzc1N...    9.0         NaN
# 18   /company/04189619/filing-history/MzE5MzEyNzcwO...    5.0         NaN
# 19   /company/04274007/filing-history/MzIwOTIxNDI1N...    6.0         NaN
# 20   /company/04418625/filing-history/MzE5MzAzMzg1M...   31.0        True
# 21   /company/04554636/filing-history/MzIwODI4MjYyN...    8.0        True
# 22   /company/04577725/filing-history/MzE5MjQ2MDM1N...    2.0         NaN
# 23   /company/04801730/filing-history/MzE5NDM3Mjc1N...   13.0        True
# 24   /company/04846529/filing-history/MzIwNTg1NTA0N...    8.0        True
# 25   /company/04964138/filing-history/MzE5Mjk1NzE2O...    3.0         NaN
# 26   /company/05047824/filing-history/MzE5NDExNzE3N...    2.0         NaN
# 27   /company/05070626/filing-history/MzA3ODkzMDE0M...    9.0         NaN
# 28   /company/05135926/filing-history/MzE5NjI2MjIxO...   15.0        True
# 29   /company/05262487/filing-history/MzE5MzE5MjMwM...    2.0         NaN
# ..                                                 ...    ...         ...
# 333  /company/10244344/filing-history/MzIwMTE1MTIzM...   12.0        True
# 334  /company/10257396/filing-history/MzIwNDI3NTQ4N...    9.0        True
# 335  /company/10277465/filing-history/MzIwMjM0NTIyM...    7.0         NaN
# 336  /company/10301271/filing-history/MzE5MDkwMzM0N...   12.0        True
# 337  /company/10325858/filing-history/MzIwNDk4NDk3N...    9.0        True
# 338  /company/10328438/filing-history/MzIwNDA0MDAwN...    6.0        True
# 339  /company/10390573/filing-history/MzIwNzcwMDM5N...    2.0         NaN
# 340  /company/10403096/filing-history/MzIxMDk0MTE1O...    6.0         NaN
# 341  /company/10408012/filing-history/MzE5NDMzMTQ3O...    7.0        True
# 342  /company/10410032/filing-history/MzIxMTc0NzQyM...    5.0        True
# 343  /company/10442998/filing-history/MzIxMDUyOTQ2N...   10.0        True
# 344  /company/10456491/filing-history/MzIxMTEzNDQ3M...    6.0         NaN
# 345  /company/10462014/filing-history/MzIxMjMxODk5M...    6.0        True
# 346  /company/10465467/filing-history/MzE5NDEwMTExO...    2.0        True
# 347  /company/10491241/filing-history/MzIxNzA2NTE1N...   14.0        True
# 348  /company/10500410/filing-history/MzIxNTE4MjM0M...    9.0        True
# 349  /company/10500564/filing-history/MzIxOTQyMjI4M...   12.0        True
# 350  /company/10501296/filing-history/MzIxMDA4NjA1N...   21.0        True
# 351  /company/10512768/filing-history/MzIxNjU2ODY5N...    1.0        True
# 352  /company/10522372/filing-history/MzIxNDQyNjg2O...    3.0         NaN
# 353  /company/10533599/filing-history/MzIxNDY0NTQ3M...   14.0        True
# 354  /company/10537683/filing-history/MzIxNTMzMTY4M...   12.0        True
# 355  /company/10539387/filing-history/MzIxNDY3OTQ3N...   24.0        True
# 356  /company/10556191/filing-history/MzIxNjQ4NzA1M...    2.0         NaN
# 18   accounts/GB-COH-04189619-2017-03-31.html     html
# 19   accounts/GB-COH-04274007-2018-03-31.html     html
# 20    accounts/GB-COH-04418625-2017-03-31.pdf      pdf
# 21    accounts/GB-COH-04554636-2017-12-31.pdf      pdf
# 22   accounts/GB-COH-04577725-2017-03-31.html     html
# 23    accounts/GB-COH-04801730-2017-03-31.pdf      pdf
# 24    accounts/GB-COH-04846529-2017-07-31.pdf      pdf
# 25   accounts/GB-COH-04964138-2017-03-31.html     html
# 26   accounts/GB-COH-05047824-2017-03-31.html     html
# 27    accounts/GB-COH-05070626-2013-03-31.pdf      pdf
# 28    accounts/GB-COH-05135926-2017-03-31.pdf      pdf
# 29   accounts/GB-COH-05262487-2017-03-31.html     html
# ..                                        ...      ...
# 333   accounts/GB-COH-10244344-2017-06-30.pdf      pdf
# 334   accounts/GB-COH-10257396-2017-06-30.pdf      pdf
# 335  accounts/GB-COH-10277465-2017-07-31.html     html
# 336   accounts/GB-COH-10301271-2017-07-31.pdf      pdf
# 337   accounts/GB-COH-10325858-2017-12-31.pdf      pdf
# 338   accounts/GB-COH-10328438-2017-08-31.pdf      pdf
# 339  accounts/GB-COH-10390573-2017-09-30.html     html
# 340  accounts/GB-COH-10403096-2017-09-30.html     html
# 341   accounts/GB-COH-10408012-2017-10-31.pdf      pdf
# 342   accounts/GB-COH-10410032-2017-10-31.pdf      pdf
# 343   accounts/GB-COH-10442998-2018-03-31.pdf      pdf
# 344  accounts/GB-COH-10456491-2017-11-30.html     html
# 345   accounts/GB-COH-10462014-2017-11-30.pdf      pdf
# 346   accounts/GB-COH-10465467-2017-03-31.pdf      pdf
# 347   accounts/GB-COH-10491241-2018-03-31.pdf      pdf
# 348   accounts/GB-COH-10500410-2017-11-30.pdf      pdf
# 349   accounts/GB-COH-10500564-2017-11-30.pdf      pdf
# 350   accounts/GB-COH-10501296-2017-08-31.pdf      pdf
# 351   accounts/GB-COH-10512768-2017-12-31.pdf      pdf
# 352  accounts/GB-COH-10522372-2018-03-31.html     html
# 353   accounts/GB-COH-10533599-2018-03-31.pdf      pdf
# 354   accounts/GB-COH-10537683-2017-12-31.pdf      pdf
# 355   accounts/GB-COH-10539387-2018-03-31.pdf      pdf
# 356  accounts/GB-COH-10556191-2018-01-31.html     html
# 357  accounts/GB-COH-10581534-2018-01-31.html     html
# 358   accounts/GB-COH-10588271-2018-01-26.pdf      pdf
# 359   accounts/GB-COH-10645942-2018-03-31.pdf      pdf
# 360  accounts/GB-COH-10689233-2017-12-31.html     html
# 361  accounts/GB-COH-10722047-2018-03-31.html     html
# 362   accounts/GB-COH-OC356377-2016-07-31.pdf      pdf
#
# [363 rows x 15 columns]

# %%
f = filing_history[
        ['company_number', 'filetype', 'filename', 'description_values.made_up_date']
    ].rename(columns={
        'description_values.made_up_date': 'financial_year_end'
    })
f.loc[:, 'charity_number'] = None
f.loc[:, 'identifier'] = 'GB-COH-' + f['company_number']
f = f.set_index('identifier')

# %%
g = accounts[['charity_number', 'filename', 'financial_year_end']]
g.loc[:, 'company_number'] = None
g.loc[:, 'identifier'] = 'GB-CHC-' + g['charity_number']
g.loc[g['filename'].notnull(), 'filetype'] = 'pdf_ocr'
g = g.set_index('identifier')

# %%
fields = ['charity_number', 'company_number', 'filetype', 'filename', 'financial_year_end']
results = pd.concat([f[fields], g.loc[g['filename'].notnull(), fields]])

# %%
orgids = pd.Series([o[0] for o in orgs])
results = results.append(pd.DataFrame(index=orgids[~orgids.isin(results.index)].rename('identifier')), sort=False)

# %%
results.to_csv("account_download_results.csv")

# %%
results.loc[results.index.str.startswith('GB-COH-').fillna(False), "org_type"] = 'Company'
results.loc[results.index.str.startswith('GB-CHC-').fillna(False), "org_type"] = 'Charity'

# %%
results.loc[
    results.index.str.contains(r'(^GB-COH-(IP|RS)|R$)').fillna(False),
    "org_type"
] = 'Registered Society'
# Out:
# c:\users\drkan\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.

# %%
results.loc[results.filename.isnull(), 'filetype'] = 'not found'

# %%
pd.crosstab(
    results.org_type,
    results.filetype,
    margins=True
).drop("All").sort_values("All", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8241eff1e87e> in <module>()
# ----> 1 pd.crosstab(
#       2     results.org_type,
#       3     results.filetype,
#       4     margins=True
#       5 ).sort_values("All", ascending=False)
#
# NameError: name 'pd' is not defined

# %%
company_types = {}
for c in tqdm_notebook(results.index):
    try:
        if c.startswith("GB-COH-"):
            r = requests.get('http://data.companieshouse.gov.uk/doc/company/{}.json'.format(c.replace('GB-COH-', '')))
            company_types[c] = r.json().get('primaryTopic', {}).get('CompanyCategory')
    except:
        print("not found for {}".format(c))
        continue
# Out:
# HBox(children=(IntProgress(value=0, max=1023), HTML(value='')))
# not found for GB-COH-04554636
# not found for nan
# not found for nan
# not found for nan
# not found for nan
# not found for nan
# not found for nan
# not found for GB-COH-00001504
# not found for GB-COH-00001589
# not found for GB-COH-00007231
# not found for GB-COH-00007721
# not found for GB-COH-00007779
# not found for GB-COH-00007812
# not found for GB-COH-0029726R
# not found for GB-COH-0030219R
# not found for GB-COH-0031409R
# not found for GB-COH-0031907R
# not found for GB-COH-0032211R
# not found for GB-COH-0032339R
# not found for GB-COH-01155534
# not found for GB-COH-02711204
# not found for GB-COH-0319444R
# not found for GB-COH-08783360)
# not found for GB-COH-0LS-1571
# not found for GB-COH-30785791
# not found for GB-COH-IP031107R

# %%
results.loc[results.org_type=='Company', "org_type"] = None
company_types = pd.Series(company_types)
results.loc[:, "org_type"] = results.org_type.fillna(company_types)

# %%
results.loc[results.org_type.str.contains('limited by guarantee', case=False).fillna(False), "org_type"] = "CLG"

# %%
results.org_type.value_counts()
# Out:
# Charity                          452
# Community Interest Company       222
# Registered Society               146
# CLG                              124
# Private Limited Company           51
# Converted/Closed                   7
# Limited Partnership                1
# Limited Liability Partnership      1
# Name: org_type, dtype: int64

# %%
results.to_csv("account_check_results.csv")
