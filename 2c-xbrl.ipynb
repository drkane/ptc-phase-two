# %% [markdown]
# # Task 2b: Extracting data from XBRL

# %%
import os
import random

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ## Fetch a sample of XBRL accounts to check

# %%
accounts = {"charity": [], "company_ixbrl": [], "company_pdf": []}
for a in os.listdir("accounts"):
    if a.startswith("GB-CHC"):
        accounts["charity"].append(a)
    elif a.startswith("GB-COH"):
        if a.endswith(".html"):
            accounts["company_ixbrl"].append(a)
        elif a.endswith(".pdf"):
            accounts["company_pdf"].append(a)

# %%
to_check = random.sample(accounts["company_ixbrl"], 10)

# %%
to_check
# Out:
# ['GB-COH-10277465-2017-07-31.html',
#  'GB-COH-07686682-2017-05-31.html',
#  'GB-COH-05047824-2017-03-31.html',
#  'GB-COH-08652494-2017-08-31.html',
#  'GB-COH-07148854-2018-03-31.html',
#  'GB-COH-07577393-2017-03-31.html',
#  'GB-COH-09168420-2017-08-31.html',
#  'GB-COH-06759419-2017-03-31.html',
#  'GB-COH-10689233-2017-12-31.html',
#  'GB-COH-09850848-2017-03-31.html']

# %% [markdown]
# ## Open accounts and parse with BeautifulSoup
#
# [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) is an engine for exploring XML files.

# %%
with open(os.path.join("accounts", to_check[0])) as a:
    soup = BeautifulSoup(a.read(), "html.parser")

# %% [markdown]
# ## Get XBRL contexts
#
# The context describes what a value applies to - either a time period or a point in time.

# %%
contexts = pd.DataFrame([{
    "id": s['id'],
    "entity": s.find('xbrli:identifier').text if s.find('xbrli:identifier') else None,
    "instant": s.find('xbrli:instant').text if s.find('xbrli:instant') else None,
    "startdate": s.find('xbrli:startdate').text if s.find('xbrli:startdate') else None,
    "enddate": s.find('xbrli:enddate').text if s.find('xbrli:enddate') else None,
} for s in soup.find_all({'xbrli:context'})]).set_index("id")
contexts
# Out:
#                                                        enddate    entity  \
# id
# bfwd_31_07_2017                                           None  10277465
# cfwd_31_07_2017                                           None  10277465
# FY_31_07_2017                                       2017-07-31  10277465
# cfwd_12_07_2016                                           None  10277465
# CountriesHypercube_FY_31_07_2017_Set1               2017-07-31  10277465
# CurrenciesHypercube_FY_31_07_2017_Set2              2017-07-31  10277465
# EntityOfficersHypercube_FY_31_07_2017_Set3          2017-07-31  10277465
# LegalFormEntityHypercube_FY_31_07_2017_Set4         2017-07-31  10277465
# AccountingStandardsAppliedHypercube_FY_31_07_20...  2017-07-31  10277465
# AccountsStatusHypercube_FY_31_07_2017_Set6          2017-07-31  10277465
# ApplicableLegislationHypercube_FY_31_07_2017_Set7   2017-07-31  10277465
# ApplicableLegislationHypercube_FY_31_07_2017_Set8   2017-07-31  10277465
# AccountsTypeHypercube_FY_31_07_2017_Set9            2017-07-31  10277465
# EntityOfficersHypercube_FY_31_07_2017_Set10         2017-07-31  10277465
# EntityContactInfoHypercube_FY_31_07_2017_Set11      2017-07-31  10277465
# Creditors-SegmentsHypercube_cfwd_31_07_2017_Set1          None  10277465
# EquitySOCI-SegmentsHypercube_cfwd_31_07_2017_Set2         None  10277465
# EquitySOCI-SegmentsHypercube_cfwd_31_07_2017_Set3         None  10277465
#
#                                                        instant   startdate
# id
# bfwd_31_07_2017                                     2016-07-12        None
# cfwd_31_07_2017                                     2017-07-31        None
# FY_31_07_2017                                             None  2016-07-13
# cfwd_12_07_2016                                     2016-07-12        None
# CountriesHypercube_FY_31_07_2017_Set1                     None  2016-07-13
# CurrenciesHypercube_FY_31_07_2017_Set2                    None  2016-07-13
# EntityOfficersHypercube_FY_31_07_2017_Set3                None  2016-07-13
# LegalFormEntityHypercube_FY_31_07_2017_Set4               None  2016-07-13
# AccountingStandardsAppliedHypercube_FY_31_07_20...        None  2016-07-13
# AccountsStatusHypercube_FY_31_07_2017_Set6                None  2016-07-13
# ApplicableLegislationHypercube_FY_31_07_2017_Set7         None  2016-07-13
# ApplicableLegislationHypercube_FY_31_07_2017_Set8         None  2016-07-13
# AccountsTypeHypercube_FY_31_07_2017_Set9                  None  2016-07-13
# EntityOfficersHypercube_FY_31_07_2017_Set10               None  2016-07-13
# EntityContactInfoHypercube_FY_31_07_2017_Set11            None  2016-07-13
# Creditors-SegmentsHypercube_cfwd_31_07_2017_Set1    2017-07-31        None
# EquitySOCI-SegmentsHypercube_cfwd_31_07_2017_Set2   2017-07-31        None
# EquitySOCI-SegmentsHypercube_cfwd_31_07_2017_Set3   2017-07-31        None

# %% [markdown]
# Do the same for units found in the data.

# %%
units = pd.DataFrame([{
    "id": s['id'],
    "measure": s.find('xbrli:measure').text if s.find('xbrli:measure') else None,
} for s in soup.find_all({'xbrli:unit'})]).set_index("id")
units
# Out:
#              measure
# id
# GBP      iso4217:GBP
# USD      iso4217:USD
# EUR      iso4217:EUR
# shares  xbrli:shares
# pure      xbrli:pure

# %% [markdown]
# ## Extract non-financial data
#
# These are values that are generally metadata about the accounts - text, dates, etc. The context is joined in to show what period each value aligns to.

# %%
nonnumeric = pd.DataFrame([{
    "context": s['contextref'],
    "name": s['name'], 
    "format": s.get('format'),
    "value": s.text.strip().replace("\n", "")
} for s in soup.find_all({'ix:nonnumeric'})])
nonnumeric = nonnumeric.join(contexts, on='context', how='left')
nonnumeric
# Out:
#                                               context  \
# 0                                       FY_31_07_2017
# 1                                       FY_31_07_2017
# 2                                       FY_31_07_2017
# 3               CountriesHypercube_FY_31_07_2017_Set1
# 4              CurrenciesHypercube_FY_31_07_2017_Set2
# 5          EntityOfficersHypercube_FY_31_07_2017_Set3
# 6                                       FY_31_07_2017
# 7                                     cfwd_31_07_2017
# 8                                     cfwd_31_07_2017
# 9                                     cfwd_31_07_2017
# 10                                      FY_31_07_2017
# 11        LegalFormEntityHypercube_FY_31_07_2017_Set4
# 12                                      FY_31_07_2017
# 13  AccountingStandardsAppliedHypercube_FY_31_07_2...
# 14         AccountsStatusHypercube_FY_31_07_2017_Set6
# 15  ApplicableLegislationHypercube_FY_31_07_2017_Set7
# 16  ApplicableLegislationHypercube_FY_31_07_2017_Set8
# 17           AccountsTypeHypercube_FY_31_07_2017_Set9
# 18           AccountsTypeHypercube_FY_31_07_2017_Set9
# 19                                      FY_31_07_2017
# 20                                      FY_31_07_2017
# 21                                      FY_31_07_2017
# 22                                      FY_31_07_2017
# 23                                      FY_31_07_2017
# 24                                      FY_31_07_2017
# 25                                      FY_31_07_2017
# 26                                      FY_31_07_2017
# 27                                      FY_31_07_2017
# 28                                      FY_31_07_2017
# 29         EntityOfficersHypercube_FY_31_07_2017_Set3
# 30     EntityContactInfoHypercube_FY_31_07_2017_Set11
# 31     EntityContactInfoHypercube_FY_31_07_2017_Set11
# 32     EntityContactInfoHypercube_FY_31_07_2017_Set11
# 33     EntityContactInfoHypercube_FY_31_07_2017_Set11
# 34     EntityContactInfoHypercube_FY_31_07_2017_Set11
# 35                                      FY_31_07_2017
# 36                                      FY_31_07_2017
# 37                                      FY_31_07_2017
# 38                                      FY_31_07_2017
# 39                                      FY_31_07_2017
# 40                                      FY_31_07_2017
# 41                                    cfwd_31_07_2017
# 42         EntityOfficersHypercube_FY_31_07_2017_Set3
# 43        LegalFormEntityHypercube_FY_31_07_2017_Set4
# 44                                      FY_31_07_2017
# 45                                      FY_31_07_2017
# 46                                      FY_31_07_2017
# 47                                      FY_31_07_2017
# 48                                      FY_31_07_2017
# 49                                    cfwd_31_07_2017
#
#                      format  \
# 0                      None
# 1                      None
# 2                      None
# 3            ixt2:nocontent
# 4            ixt2:nocontent
# 5            ixt2:nocontent
# 6                      None
# 7     ixt2:datedaymonthyear
# 8     ixt2:datedaymonthyear
# 9     ixt2:datedaymonthyear
# 10           ixt2:nocontent
# 11           ixt2:nocontent
# 12           ixt2:nocontent
# 13           ixt2:nocontent
# 14           ixt2:nocontent
# 15           ixt2:nocontent
# 16           ixt2:nocontent
# 17           ixt2:nocontent
# 18           ixt2:nocontent
# 19        ixt2:booleanfalse
# 20         ixt2:booleantrue
# 21        ixt2:booleanfalse
# 22        ixt2:booleanfalse
# 23         ixt2:booleantrue
# 24           ixt2:nocontent
# 25        ixt2:booleanfalse
# 26                     None
# 27                     None
# 28                     None
# 29                     None
# 30                     None
# 31                     None
# 32                     None
# 33                     None
# 34                     None
# 35                     None
# 36                     None
# 37                     None
# 38                     None
# 39                     None
# 40                     None
# 41  ixt2:datedaymonthyearen
# 42                     None
# 43           ixt2:nocontent
# 44                     None
# 45                     None
# 46                     None
# 47                     None
# 48                     None
# 49  ixt2:datedaymonthyearen
#
#                                                  name  \
# 0                         ns10:NameProductionSoftware
# 1                      ns10:VersionProductionSoftware
# 2               ns10:UKCompaniesHouseRegisteredNumber
# 3                ns10:CountryFormationOrIncorporation
# 4          ns10:PrincipalCurrencyUsedInBusinessReport
# 5              ns5:DirectorSigningFinancialStatements
# 6   ns5:DescriptionBodyAuthorisingFinancialStatements
# 7              ns10:StartDateForPeriodCoveredByReport
# 8                ns10:EndDateForPeriodCoveredByReport
# 9                               ns10:BalanceSheetDate
# 10                                 ns10:ScopeAccounts
# 11                               ns10:LegalFormEntity
# 12                                  ns10:ReportPeriod
# 13                    ns10:AccountingStandardsApplied
# 14              ns10:AccountsStatusAuditedOrUnaudited
# 15                         ns10:ApplicableLegislation
# 16                         ns10:ApplicableLegislation
# 17                 ns10:AccountsTypeFullOrAbbreviated
# 18                 ns10:AccountsTypeFullOrAbbreviated
# 19  ns20:CompanyHasPublishedCommitmentToUKEffectiv...
# 20  ns5:FinancialStatementsArePreparedOnGoing-conc...
# 21  ns5:DefinedBenefitPlanMulti-employerPlanTruefalse
# 22  ns5:InvestmentEntityRequiredToApplyExceptionFr...
# 23  ns5:EntityHasClaimedExemptionFromReportingDisc...
# 24                           ns10:EntityTradingStatus
# 25                        ns10:EntityDormantTruefalse
# 26              ns10:UKCompaniesHouseRegisteredNumber
# 27                                   ns10:ReportTitle
# 28            ns10:EntityCurrentLegalOrRegisteredName
# 29                             ns10:NameEntityOfficer
# 30                                  ns10:AddressLine1
# 31                                  ns10:AddressLine2
# 32                  ns10:PrincipalLocation-CityOrTown
# 33                                  ns10:CountyRegion
# 34                                 ns10:PostalCodeZip
# 35              ns10:UKCompaniesHouseRegisteredNumber
# 36                         ns10:NameEntityAccountants
# 37  ns20:StatementThatCompanyEntitledToExemptionFr...
# 38  ns20:StatementThatMembersHaveNotRequiredCompan...
# 39  ns20:StatementThatDirectorsAcknowledgeTheirRes...
# 40  ns20:StatementThatAccountsHaveBeenPreparedInAc...
# 41   ns5:DateAuthorisationFinancialStatementsForIssue
# 42                             ns10:NameEntityOfficer
# 43                               ns10:LegalFormEntity
# 44  ns5:StatementComplianceWithApplicableReporting...
# 45                       ns5:RevenueRecognitionPolicy
# 46                                      ns5:TaxPolicy
# 47                              ns5:DeferredTaxPolicy
# 48                         ns10:NameEntityAccountants
# 49                         ns17:DateAccountantsReport
#
#                                                 value     enddate    entity  \
# 0                            IRIS Accounts Production  2017-07-31  10277465
# 1                                         v18.1.0.975  2017-07-31  10277465
# 2                                            10277465  2017-07-31  10277465
# 3                                                      2017-07-31  10277465
# 4                                                      2017-07-31  10277465
# 5                                                      2017-07-31  10277465
# 6                                            director  2017-07-31  10277465
# 7                                             13.7.16        None  10277465
# 8                                             31.7.17        None  10277465
# 9                                             31.7.17        None  10277465
# 10                                                     2017-07-31  10277465
# 11                                                     2017-07-31  10277465
# 12                                                     2017-07-31  10277465
# 13                                                     2017-07-31  10277465
# 14                                                     2017-07-31  10277465
# 15                                                     2017-07-31  10277465
# 16                                                     2017-07-31  10277465
# 17                                                     2017-07-31  10277465
# 18                                                     2017-07-31  10277465
# 19                                              false  2017-07-31  10277465
# 20                                               true  2017-07-31  10277465
# 21                                              false  2017-07-31  10277465
# 22                                              false  2017-07-31  10277465
# 23                                               true  2017-07-31  10277465
# 24                                                     2017-07-31  10277465
# 25                                              false  2017-07-31  10277465
# 26                                           10277465  2017-07-31  10277465
# 27  FINANCIAL STATEMENTS FOR THE PERIOD 13 JULY 20...  2017-07-31  10277465
# 28                                MARGATE MERCURY LTD  2017-07-31  10277465
# 29                                   Miss C E Freeman  2017-07-31  10277465
# 30                                             Flat 5  2017-07-31  10277465
# 31                                  78 Northdown Road  2017-07-31  10277465
# 32                                            Margate  2017-07-31  10277465
# 33                                               Kent  2017-07-31  10277465
# 34                                            CT9 2RE  2017-07-31  10277465
# 35                                           10277465  2017-07-31  10277465
# 36                                 J Michael & Co Ltd  2017-07-31  10277465
# 37  The company is entitled to exemption from audi...  2017-07-31  10277465
# 38  The members have not required the company to o...  2017-07-31  10277465
# 39  The director acknowledges her responsibilities...  2017-07-31  10277465
# 40  The financial statements have been prepared an...  2017-07-31  10277465
# 41                                      22 March 2018        None  10277465
# 42                                   Miss C E Freeman  2017-07-31  10277465
# 43                 private company, limited by shares  2017-07-31  10277465
# 44  These financial statements have been prepared ...  2017-07-31  10277465
# 45  Turnover is measured at the fair value of the ...  2017-07-31  10277465
# 46  Taxation for the period comprises current and ...  2017-07-31  10277465
# 47  Deferred tax is recognised in respect of all t...  2017-07-31  10277465
# 48                                 J Michael & Co Ltd  2017-07-31  10277465
# 49                                      22 March 2018        None  10277465
#
#        instant   startdate
# 0         None  2016-07-13
# 1         None  2016-07-13
# 2         None  2016-07-13
# 3         None  2016-07-13
# 4         None  2016-07-13
# 5         None  2016-07-13
# 6         None  2016-07-13
# 7   2017-07-31        None
# 8   2017-07-31        None
# 9   2017-07-31        None
# 10        None  2016-07-13
# 11        None  2016-07-13
# 12        None  2016-07-13
# 13        None  2016-07-13
# 14        None  2016-07-13
# 15        None  2016-07-13
# 16        None  2016-07-13
# 17        None  2016-07-13
# 18        None  2016-07-13
# 19        None  2016-07-13
# 20        None  2016-07-13
# 21        None  2016-07-13
# 22        None  2016-07-13
# 23        None  2016-07-13
# 24        None  2016-07-13
# 25        None  2016-07-13
# 26        None  2016-07-13
# 27        None  2016-07-13
# 28        None  2016-07-13
# 29        None  2016-07-13
# 30        None  2016-07-13
# 31        None  2016-07-13
# 32        None  2016-07-13
# 33        None  2016-07-13
# 34        None  2016-07-13
# 35        None  2016-07-13
# 36        None  2016-07-13
# 37        None  2016-07-13
# 38        None  2016-07-13
# 39        None  2016-07-13
# 40        None  2016-07-13
# 41  2017-07-31        None
# 42        None  2016-07-13
# 43        None  2016-07-13
# 44        None  2016-07-13
# 45        None  2016-07-13
# 46        None  2016-07-13
# 47        None  2016-07-13
# 48        None  2016-07-13
# 49  2017-07-31        None

# %% [markdown]
# ## Extract financial data
#
# Financial data is help in `ix:nonfraction` fields. This is merged with the contexts and units to get the context for each value

# %%
df = pd.DataFrame([{
        "text": s.text,
        **s.attrs
    } for s in soup.find_all({'ix:nonfraction'})])
df = df.join(contexts, how='left', on='contextref')
df = df.join(units, how='left', on='unitref')
df
# Out:
#                                           contextref decimals  \
# 0                                    cfwd_31_07_2017        0
# 1   Creditors-SegmentsHypercube_cfwd_31_07_2017_Set1        0
# 2                                    cfwd_31_07_2017        0
# 3                                    cfwd_31_07_2017        0
# 4  EquitySOCI-SegmentsHypercube_cfwd_31_07_2017_Set2        0
# 5  EquitySOCI-SegmentsHypercube_cfwd_31_07_2017_Set3        0
# 6                                    cfwd_31_07_2017        0
# 7   Creditors-SegmentsHypercube_cfwd_31_07_2017_Set1        0
#
#                format                                   name scale sign  \
# 0  ixt2:numdotdecimal                     ns5:CashBankOnHand     0  NaN
# 1  ixt2:numdotdecimal                          ns5:Creditors     0  NaN
# 2  ixt2:numdotdecimal        ns5:NetCurrentAssetsLiabilities     0    -
# 3  ixt2:numdotdecimal  ns5:TotalAssetsLessCurrentLiabilities     0    -
# 4                 NaN                             ns5:Equity     0  NaN
# 5  ixt2:numdotdecimal                             ns5:Equity     0    -
# 6  ixt2:numdotdecimal                             ns5:Equity     0    -
# 7  ixt2:numdotdecimal                     ns5:OtherCreditors     0  NaN
#
#     text unitref                             xmlns:ix enddate    entity  \
# 0  1,636     GBP  http://www.xbrl.org/2013/inlineXBRL    None  10277465
# 1  2,971     GBP  http://www.xbrl.org/2013/inlineXBRL    None  10277465
# 2  1,335     GBP  http://www.xbrl.org/2013/inlineXBRL    None  10277465
# 3  1,335     GBP  http://www.xbrl.org/2013/inlineXBRL    None  10277465
# 4      1     GBP  http://www.xbrl.org/2013/inlineXBRL    None  10277465
# 5  1,336     GBP  http://www.xbrl.org/2013/inlineXBRL    None  10277465
# 6  1,335     GBP  http://www.xbrl.org/2013/inlineXBRL    None  10277465
# 7  2,971     GBP  http://www.xbrl.org/2013/inlineXBRL    None  10277465
#
#       instant startdate      measure
# 0  2017-07-31      None  iso4217:GBP
# 1  2017-07-31      None  iso4217:GBP
# 2  2017-07-31      None  iso4217:GBP
# 3  2017-07-31      None  iso4217:GBP
# 4  2017-07-31      None  iso4217:GBP
# 5  2017-07-31      None  iso4217:GBP
# 6  2017-07-31      None  iso4217:GBP
# 7  2017-07-31      None  iso4217:GBP

# %%
if 'value' not in df.columns:
    df.loc[:, "value"] = df["text"].str.replace(',', '')

# %% [markdown]
# Sort out the values to produce a proper value. This is done by:
#
# - replace any items that are just a dash with a 0
# - replacing any non-numeric characters in the field with nothing
# - converting to a float
# - multiplying by -1 if the "sign" field has a "-" in it

# %%
df.loc[:, "value_c"] = df.value.str.replace(r'[^0-9\.]', "").astype(float) * df.sign.apply(lambda x: -1 if x=="-" else 1)
df['value_c']
# Out:
# 0    1636.0
# 1    2971.0
# 2   -1335.0
# 3   -1335.0
# 4       1.0
# 5   -1336.0
# 6   -1335.0
# 7    2971.0
# Name: value_c, dtype: float64

# %%
df[["contextref", "format", "name", "value_c"]]
# Out:
#                                           contextref              format  \
# 0                                    cfwd_31_07_2017  ixt2:numdotdecimal
# 1   Creditors-SegmentsHypercube_cfwd_31_07_2017_Set1  ixt2:numdotdecimal
# 2                                    cfwd_31_07_2017  ixt2:numdotdecimal
# 3                                    cfwd_31_07_2017  ixt2:numdotdecimal
# 4  EquitySOCI-SegmentsHypercube_cfwd_31_07_2017_Set2                 NaN
# 5  EquitySOCI-SegmentsHypercube_cfwd_31_07_2017_Set3  ixt2:numdotdecimal
# 6                                    cfwd_31_07_2017  ixt2:numdotdecimal
# 7   Creditors-SegmentsHypercube_cfwd_31_07_2017_Set1  ixt2:numdotdecimal
#
#                                     name  value_c
# 0                     ns5:CashBankOnHand   1636.0
# 1                          ns5:Creditors   2971.0
# 2        ns5:NetCurrentAssetsLiabilities  -1335.0
# 3  ns5:TotalAssetsLessCurrentLiabilities  -1335.0
# 4                             ns5:Equity      1.0
# 5                             ns5:Equity  -1336.0
# 6                             ns5:Equity  -1335.0
# 7                     ns5:OtherCreditors   2971.0

# %% [markdown]
# ## Discovery of contents of XBRL files
#
# This is a quick exercise to discover what is in XBRL files.

# %%
from collections import Counter

# %% [markdown]
# Open all our XBRL accounts and look for any tags with a `:` in them, and also the schema used.

# %%
counts = {}
for t in accounts["company_ixbrl"]:
    with open(os.path.join("accounts", t), encoding='utf8') as a:
        soup = BeautifulSoup(a.read(), "html.parser")
        counts[t] = dict(Counter([tag.name for tag in soup.find_all() if ":" in tag.name]))
        counts[t]['schema'] = soup.find({'link:schemaref'}).get('xlink:href', '').strip()

# %% [markdown]
# Turn this into a dataframe with the tags and a series with the schema.

# %%
counts_df = pd.DataFrame(counts).T.fillna(0)
schema = counts_df['schema']
counts_df = counts_df[[c for c in counts_df.columns if c != 'schema']]

# %% [markdown]
# Show the prevelance of different schemas

# %%
schema.value_counts()
# Out:
# https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS-102-2014-09-01.xsd          73
# http://www.xbrl.org/uk/gaap/core/2009-09-01/uk-gaap-full-2009-09-01.xsd    36
# https://xbrl.frc.org.uk/char/2016-01-01/char-2016-01-01.xsd                 1
# https://xbrl.frc.org.uk/IFRS/2014-09-01/IFRS-2014-09-01.xsd                 1
# Name: schema, dtype: int64

# %% [markdown]
# Work out the number of accounts of each schema type with different tags. Divide by the schema types to show the proportion of accounts of that type with each tag.

# %%
totals = counts_df.astype(bool).join(schema).groupby("schema").sum().T
(totals / schema.value_counts()).multiply(100).round(1)
# Out:
#                                                     http://www.xbrl.org/uk/gaap/core/2009-09-01/uk-gaap-full-2009-09-01.xsd  \
# core:parententityorcontrollingpartyandultimatec...                                                0.0
# core:xeventafterreportingdategroupingdimension....                                                0.0
# core:xotherspecificaccountingpolicygroupingdime...                                                0.0
# frs-common:analysisdimension.domain                                                               0.0
# frs-core:parententityorcontrollingpartyandultim...                                                0.0
# frs-core:xeventafterreportingdategroupingdimens...                                                0.0
# ix:continuation                                                                                   0.0
# ix:exclude                                                                                        0.0
# ix:header                                                                                       100.0
# ix:hidden                                                                                       100.0
# ix:nonfraction                                                                                  100.0
# ix:nonnumeric                                                                                   100.0
# ix:references                                                                                   100.0
# ix:resources                                                                                    100.0
# ix:tuple                                                                                          8.3
# link:schemaref                                                                                  100.0
# ns10:xotherspecificaccountingpolicygroupingdime...                                                0.0
# xbrldi:explicitmember                                                                           100.0
# xbrldi:typedmember                                                                                0.0
# xbrli:context                                                                                     5.6
# xbrli:enddate                                                                                     5.6
# xbrli:entity                                                                                      5.6
# xbrli:identifier                                                                                  5.6
# xbrli:instant                                                                                     5.6
# xbrli:measure                                                                                     5.6
# xbrli:period                                                                                      5.6
# xbrli:segment                                                                                     5.6
# xbrli:startdate                                                                                   5.6
# xbrli:unit                                                                                        5.6
#
#                                                     https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS-102-2014-09-01.xsd  \
# core:parententityorcontrollingpartyandultimatec...                                                1.4
# core:xeventafterreportingdategroupingdimension....                                               11.0
# core:xotherspecificaccountingpolicygroupingdime...                                                1.4
# frs-common:analysisdimension.domain                                                               5.5
# frs-core:parententityorcontrollingpartyandultim...                                                5.5
# frs-core:xeventafterreportingdategroupingdimens...                                                5.5
# ix:continuation                                                                                   5.5
# ix:exclude                                                                                        5.5
# ix:header                                                                                       100.0
# ix:hidden                                                                                       100.0
# ix:nonfraction                                                                                  100.0
# ix:nonnumeric                                                                                   100.0
# ix:references                                                                                   100.0
# ix:resources                                                                                    100.0
# ix:tuple                                                                                          0.0
# link:schemaref                                                                                  100.0
# ns10:xotherspecificaccountingpolicygroupingdime...                                                0.0
# xbrldi:explicitmember                                                                           100.0
# xbrldi:typedmember                                                                               19.2
# xbrli:context                                                                                    97.3
# xbrli:enddate                                                                                    97.3
# xbrli:entity                                                                                     97.3
# xbrli:identifier                                                                                 97.3
# xbrli:instant                                                                                    97.3
# xbrli:measure                                                                                    97.3
# xbrli:period                                                                                     97.3
# xbrli:segment                                                                                    97.3
# xbrli:startdate                                                                                  97.3
# xbrli:unit                                                                                       97.3
#
#                                                     https://xbrl.frc.org.uk/IFRS/2014-09-01/IFRS-2014-09-01.xsd  \
# core:parententityorcontrollingpartyandultimatec...                                                0.0
# core:xeventafterreportingdategroupingdimension....                                                0.0
# core:xotherspecificaccountingpolicygroupingdime...                                                0.0
# frs-common:analysisdimension.domain                                                               0.0
# frs-core:parententityorcontrollingpartyandultim...                                                0.0
# frs-core:xeventafterreportingdategroupingdimens...                                                0.0
# ix:continuation                                                                                   0.0
# ix:exclude                                                                                        0.0
# ix:header                                                                                       100.0
# ix:hidden                                                                                       100.0
# ix:nonfraction                                                                                  100.0
# ix:nonnumeric                                                                                   100.0
# ix:references                                                                                   100.0
# ix:resources                                                                                    100.0
# ix:tuple                                                                                          0.0
# link:schemaref                                                                                  100.0
# ns10:xotherspecificaccountingpolicygroupingdime...                                                0.0
# xbrldi:explicitmember                                                                           100.0
# xbrldi:typedmember                                                                                0.0
# xbrli:context                                                                                   100.0
# xbrli:enddate                                                                                   100.0
# xbrli:entity                                                                                    100.0
# xbrli:identifier                                                                                100.0
# xbrli:instant                                                                                   100.0
# xbrli:measure                                                                                   100.0
# xbrli:period                                                                                    100.0
# xbrli:segment                                                                                   100.0
# xbrli:startdate                                                                                 100.0
# xbrli:unit                                                                                      100.0
#
#                                                     https://xbrl.frc.org.uk/char/2016-01-01/char-2016-01-01.xsd
# core:parententityorcontrollingpartyandultimatec...                                                0.0
# core:xeventafterreportingdategroupingdimension....                                                0.0
# core:xotherspecificaccountingpolicygroupingdime...                                                0.0
# frs-common:analysisdimension.domain                                                               0.0
# frs-core:parententityorcontrollingpartyandultim...                                                0.0
# frs-core:xeventafterreportingdategroupingdimens...                                                0.0
# ix:continuation                                                                                   0.0
# ix:exclude                                                                                        0.0
# ix:header                                                                                       100.0
# ix:hidden                                                                                       100.0
# ix:nonfraction                                                                                  100.0
# ix:nonnumeric                                                                                   100.0
# ix:references                                                                                   100.0
# ix:resources                                                                                    100.0
# ix:tuple                                                                                          0.0
# link:schemaref                                                                                  100.0
# ns10:xotherspecificaccountingpolicygroupingdime...                                              100.0
# xbrldi:explicitmember                                                                           100.0
# xbrldi:typedmember                                                                              100.0
# xbrli:context                                                                                   100.0
# xbrli:enddate                                                                                   100.0
# xbrli:entity                                                                                    100.0
# xbrli:identifier                                                                                100.0
# xbrli:instant                                                                                   100.0
# xbrli:measure                                                                                   100.0
# xbrli:period                                                                                    100.0
# xbrli:segment                                                                                   100.0
# xbrli:startdate                                                                                 100.0
# xbrli:unit                                                                                      100.0

# %%
counts_df.median().sort_values(ascending=False)
# Out:
# ix:nonnumeric                                                                                 26.0
# ix:nonfraction                                                                                18.0
# xbrli:period                                                                                  12.0
# xbrli:identifier                                                                              12.0
# xbrli:entity                                                                                  12.0
# xbrli:context                                                                                 12.0
# xbrldi:explicitmember                                                                         11.0
# xbrli:segment                                                                                  9.0
# xbrli:enddate                                                                                  7.0
# xbrli:startdate                                                                                7.0
# xbrli:instant                                                                                  6.0
# ix:resources                                                                                   1.0
# ix:header                                                                                      1.0
# ix:hidden                                                                                      1.0
# ix:references                                                                                  1.0
# xbrli:unit                                                                                     1.0
# link:schemaref                                                                                 1.0
# xbrli:measure                                                                                  1.0
# core:xotherspecificaccountingpolicygroupingdimension.domain                                    0.0
# frs-core:xeventafterreportingdategroupingdimension.domain                                      0.0
# core:xeventafterreportingdategroupingdimension.domain                                          0.0
# frs-common:analysisdimension.domain                                                            0.0
# frs-core:parententityorcontrollingpartyandultimatecontrollingpartygroupingdimension.domain     0.0
# ix:tuple                                                                                       0.0
# ix:continuation                                                                                0.0
# ix:exclude                                                                                     0.0
# ns10:xotherspecificaccountingpolicygroupingdimension.domain                                    0.0
# xbrldi:typedmember                                                                             0.0
# core:parententityorcontrollingpartyandultimatecontrollingpartygroupingdimension.domain         0.0
# dtype: float64

# %%
schema
# Out:
# GB-COH-00889858-2017-09-30.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-02978957-2017-10-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-03054343-2017-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-03171108-2017-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-03874497-2017-10-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-04001326-2017-05-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-04173535-2017-09-30.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-04189619-2017-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-04274007-2018-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-04577725-2017-03-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-04964138-2017-03-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-05047824-2017-03-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-05262487-2017-03-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-05298085-2017-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-05642581-2017-12-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-05677069-2016-12-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-05766631-2018-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-05786202-2017-03-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-05969206-2017-10-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-05970967-2017-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-05976127-2018-10-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-06269027-2017-06-30.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-06270922-2016-11-30.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-06285509-2017-06-30.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-06299911-2017-03-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-06352540-2017-03-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-06488693-2018-01-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-06569976-2018-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-06585052-2018-03-31.html    https://xbrl.frc.org.uk/char/2016-01-01/char-2...
# GB-COH-06668777-2017-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
#                                                          ...
# GB-COH-09168420-2017-08-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-09242457-2017-09-30.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-09268330-2017-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-09328647-2017-11-30.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-09399940-2018-01-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-09405323-2018-01-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-09430326-2017-03-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-09564232-2016-04-30.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-09606122-2017-05-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-09735034-2017-08-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-09850848-2017-03-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-09887269-2017-11-30.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-09893909-2017-11-30.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-09926931-2018-05-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-09953081-2017-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-10087608-2018-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-10137386-2017-04-30.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-10157965-2017-04-30.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-10195133-2017-05-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-10227051-2017-06-30.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-10227734-2017-03-31.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-10277465-2017-07-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-10390573-2017-09-30.html    http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# GB-COH-10403096-2017-09-30.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-10456491-2017-11-30.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-10522372-2018-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-10556191-2018-01-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-10581534-2018-01-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-10689233-2017-12-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# GB-COH-10722047-2018-03-31.html    https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# Name: schema, Length: 111, dtype: object
